# %% [markdown]
# #Exercises
# ## Download ECSSD dataset with 1000 images containing image and binary mask pair. Rescale all those images to 224x224 sizes before any training and testing.
# [Note: Try to avoid dl2 library. Use GPU]
# ## You will be solving supervised image segmentation problem instead of classification.
# ## Split 1000 images into 70:10:20 for train-validation-test.
# ## Use Dice Coefficient loss
#
# ##1) Modify GoogLeNet for 224x224 size for image segmentation, perform training and testing on ECSSD dataset.[4 Marks]
#
# ##2) Do the same thing for ResNet [4 Marks]
#
# ##3) Provide observation related to better model for this dataset. [2 Marks]
# ## Note: Implement all models from Scratch.

# %% [markdown]
# ## Data download and preprocessing.

# %%
import os
import requests
from zipfile import ZipFile
from PIL import Image
from io import BytesIO
import random
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms

# Define the URL and paths
dataset_url = "http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/images.zip"
mask_url = "http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/ground_truth_mask.zip"
dataset_path = "ECSSD"
image_path = os.path.join(dataset_path, "images", "images")
mask_path = os.path.join(dataset_path, "masks", "ground_truth_mask")
resized_image_path = os.path.join(dataset_path, "resized_images")
resized_mask_path = os.path.join(dataset_path, "resized_masks")

# Create directories
os.makedirs(image_path, exist_ok=True)
os.makedirs(mask_path, exist_ok=True)
os.makedirs(resized_image_path, exist_ok=True)
os.makedirs(resized_mask_path, exist_ok=True)

# Function to download and extract zip files
def download_and_extract(url, extract_to):
    response = requests.get(url)
    with ZipFile(BytesIO(response.content)) as zip_ref:
        zip_ref.extractall(extract_to)

# Function to resize images
def resize_images(input_dir, output_dir, size=(224, 224)):
    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            img_path = os.path.join(input_dir, filename)
            img = Image.open(img_path)
            img_resized = img.resize(size, Image.LANCZOS)
            img_resized.save(os.path.join(output_dir, filename))
            print(f"Resized and saved {filename}")

# Check if dataset is already downloaded
if os.path.exists(image_path) and os.path.exists(mask_path):
    print("Dataset is already downloaded.")
else:
    # Download and extract images and masks
    download_and_extract(dataset_url, image_path)
    download_and_extract(mask_url, mask_path)

# Resize images and masks
resize_images(image_path, resized_image_path)
resize_images(mask_path, resized_mask_path)

print("Images and masks have been resized and saved.")

# Split dataset
all_images = os.listdir(resized_image_path)
train_images, test_images = train_test_split(all_images, test_size=0.2, random_state=42)
train_images, val_images = train_test_split(train_images, test_size=0.125, random_state=42)  # 0.125 * 0.8 = 0.1

print("Dataset has been split into training, validation, and test sets.")
print(f"Number of training images: {len(train_images)}")
print(f"Number of validation images: {len(val_images)}")
print(f"Number of test images: {len(test_images)}")
# Out:
# Dataset is already downloaded.
# Resized and saved 0001.jpg
# Resized and saved 0002.jpg
# Resized and saved 0003.jpg
# Resized and saved 0004.jpg
# Resized and saved 0005.jpg
# Resized and saved 0006.jpg
# Resized and saved 0007.jpg
# Resized and saved 0008.jpg
# Resized and saved 0009.jpg
# Resized and saved 0010.jpg
# Resized and saved 0011.jpg
# Resized and saved 0012.jpg
# Resized and saved 0013.jpg
# Resized and saved 0014.jpg
# Resized and saved 0015.jpg
# Resized and saved 0016.jpg
# Resized and saved 0017.jpg
# Resized and saved 0018.jpg
# Resized and saved 0019.jpg
# Resized and saved 0020.jpg
# Resized and saved 0021.jpg
# Resized and saved 0022.jpg
# Resized and saved 0023.jpg
# Resized and saved 0024.jpg
# Resized and saved 0025.jpg
# Resized and saved 0026.jpg
# Resized and saved 0027.jpg
# Resized and saved 0028.jpg
# Resized and saved 0029.jpg
# Resized and saved 0030.jpg
# Resized and saved 0031.jpg
# Resized and saved 0032.jpg
# Resized and saved 0033.jpg
# Resized and saved 0034.jpg
# Resized and saved 0035.jpg
# Resized and saved 0036.jpg
# Resized and saved 0037.jpg
# Resized and saved 0038.jpg
# Resized and saved 0039.jpg
# Resized and saved 0040.jpg
# Resized and saved 0041.jpg
# Resized and saved 0042.jpg
# Resized and saved 0043.jpg
# Resized and saved 0044.jpg
# Resized and saved 0045.jpg
# Resized and saved 0046.jpg
# Resized and saved 0047.jpg
# Resized and saved 0048.jpg
# Resized and saved 0049.jpg
# Resized and saved 0050.jpg
# Resized and saved 0051.jpg
# Resized and saved 0052.jpg
# Resized and saved 0053.jpg
# Resized and saved 0054.jpg
# Resized and saved 0055.jpg
# Resized and saved 0056.jpg
# Resized and saved 0057.jpg
# Resized and saved 0058.jpg
# Resized and saved 0059.jpg
# Resized and saved 0060.jpg
# Resized and saved 0061.jpg
# Resized and saved 0062.jpg
# Resized and saved 0063.jpg
# Resized and saved 0064.jpg
# Resized and saved 0065.jpg
# Resized and saved 0066.jpg
# Resized and saved 0067.jpg
# Resized and saved 0068.jpg
# Resized and saved 0069.jpg
# Resized and saved 0070.jpg
# Resized and saved 0071.jpg
# Resized and saved 0072.jpg
# Resized and saved 0073.jpg
# Resized and saved 0074.jpg
# Resized and saved 0075.jpg
# Resized and saved 0076.jpg
# Resized and saved 0077.jpg
# Resized and saved 0078.jpg
# Resized and saved 0079.jpg
# Resized and saved 0080.jpg
# Resized and saved 0081.jpg
# Resized and saved 0082.jpg
# Resized and saved 0083.jpg
# Resized and saved 0084.jpg
# Resized and saved 0085.jpg
# Resized and saved 0086.jpg
# Resized and saved 0087.jpg
# Resized and saved 0088.jpg
# Resized and saved 0089.jpg
# Resized and saved 0090.jpg
# Resized and saved 0091.jpg
# Resized and saved 0092.jpg
# Resized and saved 0093.jpg
# Resized and saved 0094.jpg
# Resized and saved 0095.jpg
# Resized and saved 0096.jpg
# Resized and saved 0097.jpg
# Resized and saved 0098.jpg
# Resized and saved 0099.jpg
# Resized and saved 0100.jpg
# Resized and saved 0101.jpg
# Resized and saved 0102.jpg
# Resized and saved 0103.jpg
# Resized and saved 0104.jpg
# Resized and saved 0105.jpg
# Resized and saved 0106.jpg
# Resized and saved 0107.jpg
# Resized and saved 0108.jpg
# Resized and saved 0109.jpg
# Resized and saved 0110.jpg
# Resized and saved 0111.jpg
# Resized and saved 0112.jpg
# Resized and saved 0113.jpg
# Resized and saved 0114.jpg
# Resized and saved 0720.jpg
# Resized and saved 0721.jpg
# Resized and saved 0722.jpg
# Resized and saved 0723.jpg
# Resized and saved 0724.jpg
# Resized and saved 0725.jpg
# Resized and saved 0726.jpg
# Resized and saved 0727.jpg
# Resized and saved 0728.jpg
# Resized and saved 0729.jpg
# Resized and saved 0730.jpg
# Resized and saved 0731.jpg
# Resized and saved 0732.jpg
# Resized and saved 0733.jpg
# Resized and saved 0734.jpg
# Resized and saved 0735.jpg
# Resized and saved 0736.jpg
# Resized and saved 0737.jpg
# Resized and saved 0738.jpg
# Resized and saved 0739.jpg
# Resized and saved 0740.jpg
# Resized and saved 0741.jpg
# Resized and saved 0742.jpg
# Resized and saved 0743.jpg
# Resized and saved 0744.jpg
# Resized and saved 0745.jpg
# Resized and saved 0746.jpg
# Resized and saved 0747.jpg
# Resized and saved 0748.jpg
# Resized and saved 0749.jpg
# Resized and saved 0750.jpg
# Resized and saved 0751.jpg
# Resized and saved 0752.jpg
# Resized and saved 0753.jpg
# Resized and saved 0754.jpg
# Resized and saved 0755.jpg
# Resized and saved 0756.jpg
# Resized and saved 0757.jpg
# Resized and saved 0758.jpg
# Resized and saved 0759.jpg
# Resized and saved 0760.jpg
# Resized and saved 0761.jpg
# Resized and saved 0762.jpg
# Resized and saved 0763.jpg
# Resized and saved 0764.jpg
# Resized and saved 0765.jpg
# Resized and saved 0766.jpg
# Resized and saved 0767.jpg
# Resized and saved 0768.jpg
# Resized and saved 0769.jpg
# Resized and saved 0770.jpg
# Resized and saved 0771.jpg
# Resized and saved 0772.jpg
# Resized and saved 0773.jpg
# Resized and saved 0774.jpg
# Resized and saved 0775.jpg
# Resized and saved 0776.jpg
# Resized and saved 0777.jpg
# Resized and saved 0778.jpg
# Resized and saved 0779.jpg
# Resized and saved 0780.jpg
# Resized and saved 0781.jpg
# Resized and saved 0782.jpg
# Resized and saved 0783.jpg
# Resized and saved 0784.jpg
# Resized and saved 0785.jpg
# Resized and saved 0786.jpg
# Resized and saved 0787.jpg
# Resized and saved 0788.jpg
# Resized and saved 0789.jpg
# Resized and saved 0790.jpg
# Resized and saved 0791.jpg
# Resized and saved 0792.jpg
# Resized and saved 0793.jpg
# Resized and saved 0794.jpg
# Resized and saved 0795.jpg
# Resized and saved 0796.jpg
# Resized and saved 0797.jpg
# Resized and saved 0798.jpg
# Resized and saved 0799.jpg
# Resized and saved 0800.jpg
# Resized and saved 0801.jpg
# Resized and saved 0802.jpg
# Resized and saved 0803.jpg
# Resized and saved 0804.jpg
# Resized and saved 0805.jpg
# Resized and saved 0806.jpg
# Resized and saved 0807.jpg
# Resized and saved 0808.jpg
# Resized and saved 0809.jpg
# Resized and saved 0810.jpg
# Resized and saved 0811.jpg
# Resized and saved 0812.jpg
# Resized and saved 0813.jpg
# Resized and saved 0814.jpg
# Resized and saved 0815.jpg
# Resized and saved 0816.jpg
# Resized and saved 0817.jpg
# Resized and saved 0818.jpg
# Resized and saved 0819.jpg
# Resized and saved 0820.jpg
# Resized and saved 0821.jpg
# Resized and saved 0822.jpg
# Resized and saved 0823.jpg
# Resized and saved 0824.jpg
# Resized and saved 0825.jpg
# Resized and saved 0826.jpg
# Resized and saved 0827.jpg
# Resized and saved 0828.jpg
# Resized and saved 0829.jpg
# Resized and saved 0830.jpg
# Resized and saved 0831.jpg
# Resized and saved 0832.jpg
# Resized and saved 0833.jpg
# Resized and saved 0834.jpg
# Resized and saved 0835.jpg
# Resized and saved 0836.jpg
# Resized and saved 0837.jpg
# Resized and saved 0838.jpg
# Resized and saved 0839.jpg
# Resized and saved 0840.jpg
# Resized and saved 0841.jpg
# Resized and saved 0842.jpg
# Resized and saved 0843.jpg
# Resized and saved 0844.jpg
# Resized and saved 0845.jpg
# Resized and saved 0846.jpg
# Resized and saved 0847.jpg
# Resized and saved 0848.jpg
# Resized and saved 0849.jpg
# Resized and saved 0850.jpg
# Resized and saved 0851.jpg
# Resized and saved 0852.jpg
# Resized and saved 0853.jpg
# Resized and saved 0854.jpg
# Resized and saved 0855.jpg
# Resized and saved 0856.jpg
# Resized and saved 0857.jpg
# Resized and saved 0858.jpg
# Resized and saved 0859.jpg
# Resized and saved 0860.jpg
# Resized and saved 0861.jpg
# Resized and saved 0862.jpg
# Resized and saved 0863.jpg
# Resized and saved 0864.jpg
# Resized and saved 0865.jpg
# Resized and saved 0866.jpg
# Resized and saved 0867.jpg
# Resized and saved 0868.jpg
# Resized and saved 0869.jpg
# Resized and saved 0870.jpg
# Resized and saved 0871.jpg
# Resized and saved 0872.jpg
# Resized and saved 0873.jpg
# Resized and saved 0874.jpg
# Resized and saved 0875.jpg
# Resized and saved 0876.jpg
# Resized and saved 0877.jpg
# Resized and saved 0878.jpg
# Resized and saved 0879.jpg
# Resized and saved 0880.jpg
# Resized and saved 0881.jpg
# Resized and saved 0882.jpg
# Resized and saved 0883.jpg
# Resized and saved 0884.jpg
# Resized and saved 0885.jpg
# Resized and saved 0886.jpg
# Resized and saved 0887.jpg
# Resized and saved 0888.jpg
# Resized and saved 0889.jpg
# Resized and saved 0890.jpg
# Resized and saved 0891.jpg
# Resized and saved 0892.jpg
# Resized and saved 0893.jpg
# Resized and saved 0894.jpg
# Resized and saved 0895.jpg
# Resized and saved 0896.jpg
# Resized and saved 0897.jpg
# Resized and saved 0898.jpg
# Resized and saved 0899.jpg
# Resized and saved 0900.jpg
# Resized and saved 0901.jpg
# Resized and saved 0902.jpg
# Resized and saved 0903.jpg
# Resized and saved 0904.jpg
# Resized and saved 0905.jpg
# Resized and saved 0906.jpg
# Resized and saved 0907.jpg
# Resized and saved 0908.jpg
# Resized and saved 0909.jpg
# Resized and saved 0910.jpg
# Resized and saved 0911.jpg
# Resized and saved 0912.jpg
# Resized and saved 0913.jpg
# Resized and saved 0914.jpg
# Resized and saved 0915.jpg
# Resized and saved 0916.jpg
# Resized and saved 0917.jpg
# Resized and saved 0918.jpg
# Resized and saved 0919.jpg
# Resized and saved 0920.jpg
# Resized and saved 0921.jpg
# Resized and saved 0922.jpg
# Resized and saved 0923.jpg
# Resized and saved 0924.jpg
# Resized and saved 0925.jpg
# Resized and saved 0926.jpg
# Resized and saved 0927.jpg
# Resized and saved 0928.jpg
# Resized and saved 0929.jpg
# Resized and saved 0930.jpg
# Resized and saved 0931.jpg
# Resized and saved 0932.jpg
# Resized and saved 0933.jpg
# Resized and saved 0934.jpg
# Resized and saved 0935.jpg
# Resized and saved 0936.jpg
# Resized and saved 0937.jpg
# Resized and saved 0938.jpg
# Resized and saved 0939.jpg
# Resized and saved 0940.jpg
# Resized and saved 0941.jpg
# Resized and saved 0942.jpg
# Resized and saved 0943.jpg
# Resized and saved 0944.jpg
# Resized and saved 0945.jpg
# Resized and saved 0946.jpg
# Resized and saved 0947.jpg
# Resized and saved 0948.jpg
# Resized and saved 0949.jpg
# Resized and saved 0950.jpg
# Resized and saved 0951.jpg
# Resized and saved 0952.jpg
# Resized and saved 0953.jpg
# Resized and saved 0954.jpg
# Resized and saved 0955.jpg
# Resized and saved 0956.jpg
# Resized and saved 0957.jpg
# Resized and saved 0958.jpg
# Resized and saved 0959.jpg
# Resized and saved 0960.jpg
# Resized and saved 0961.jpg
# Resized and saved 0962.jpg
# Resized and saved 0963.jpg
# Resized and saved 0964.jpg
# Resized and saved 0965.jpg
# Resized and saved 0966.jpg
# Resized and saved 0967.jpg
# Resized and saved 0968.jpg
# Resized and saved 0969.jpg
# Resized and saved 0970.jpg
# Resized and saved 0971.jpg
# Resized and saved 0972.jpg
# Resized and saved 0973.jpg
# Resized and saved 0974.jpg
# Resized and saved 0975.jpg
# Resized and saved 0976.jpg
# Resized and saved 0977.jpg
# Resized and saved 0978.jpg
# Resized and saved 0979.jpg
# Resized and saved 0980.jpg
# Resized and saved 0981.jpg
# Resized and saved 0982.jpg
# Resized and saved 0983.jpg
# Resized and saved 0984.jpg
# Resized and saved 0985.jpg
# Resized and saved 0986.jpg
# Resized and saved 0987.jpg
# Resized and saved 0988.jpg
# Resized and saved 0989.jpg
# Resized and saved 0990.jpg
# Resized and saved 0991.jpg
# Resized and saved 0992.jpg
# Resized and saved 0993.jpg
# Resized and saved 0994.jpg
# Resized and saved 0995.jpg
# Resized and saved 0996.jpg
# Resized and saved 0997.jpg
# Resized and saved 0998.jpg
# Resized and saved 0999.jpg
# Resized and saved 1000.jpg
# Resized and saved 0001.png
# Resized and saved 0002.png
# Resized and saved 0003.png
# Resized and saved 0004.png
# Resized and saved 0005.png
# Resized and saved 0006.png
# Resized and saved 0007.png
# Resized and saved 0008.png
# Resized and saved 0009.png
# Resized and saved 0010.png
# Resized and saved 0011.png
# Resized and saved 0012.png
# Resized and saved 0013.png
# Resized and saved 0014.png
# Resized and saved 0015.png
# Resized and saved 0016.png
# Resized and saved 0017.png
# Resized and saved 0018.png
# Resized and saved 0019.png
# Resized and saved 0020.png
# Resized and saved 0021.png
# Resized and saved 0022.png
# Resized and saved 0023.png
# Resized and saved 0024.png
# Resized and saved 0025.png
# Resized and saved 0026.png
# Resized and saved 0027.png
# Resized and saved 0028.png
# Resized and saved 0029.png
# Resized and saved 0030.png
# Resized and saved 0031.png
# Resized and saved 0032.png
# Resized and saved 0033.png
# Resized and saved 0034.png
# Resized and saved 0035.png
# Resized and saved 0036.png
# Resized and saved 0037.png
# Resized and saved 0038.png
# Resized and saved 0039.png
# Resized and saved 0040.png
# Resized and saved 0041.png
# Resized and saved 0042.png
# Resized and saved 0043.png
# Resized and saved 0044.png
# Resized and saved 0045.png
# Resized and saved 0046.png
# Resized and saved 0047.png
# Resized and saved 0048.png
# Resized and saved 0049.png
# Resized and saved 0050.png
# Resized and saved 0051.png
# Resized and saved 0052.png
# Resized and saved 0053.png
# Resized and saved 0054.png
# Resized and saved 0055.png
# Resized and saved 0056.png
# Resized and saved 0057.png
# Resized and saved 0058.png
# Resized and saved 0059.png
# Resized and saved 0060.png
# Resized and saved 0061.png
# Resized and saved 0062.png
# Resized and saved 0063.png
# Resized and saved 0064.png
# Resized and saved 0065.png
# Resized and saved 0066.png
# Resized and saved 0067.png
# Resized and saved 0068.png
# Resized and saved 0069.png
# Resized and saved 0070.png
# Resized and saved 0071.png
# Resized and saved 0072.png
# Resized and saved 0073.png
# Resized and saved 0074.png
# Resized and saved 0075.png
# Resized and saved 0076.png
# Resized and saved 0077.png
# Resized and saved 0078.png
# Resized and saved 0079.png
# Resized and saved 0080.png
# Resized and saved 0081.png
# Resized and saved 0082.png
# Resized and saved 0083.png
# Resized and saved 0084.png
# Resized and saved 0085.png
# Resized and saved 0086.png
# Resized and saved 0087.png
# Resized and saved 0088.png
# Resized and saved 0089.png
# Resized and saved 0090.png
# Resized and saved 0091.png
# Resized and saved 0092.png
# Resized and saved 0093.png
# Resized and saved 0094.png
# Resized and saved 0095.png
# Resized and saved 0096.png
# Resized and saved 0097.png
# Resized and saved 0098.png
# Resized and saved 0099.png
# Resized and saved 0100.png
# Resized and saved 0101.png
# Resized and saved 0102.png
# Resized and saved 0103.png
# Resized and saved 0104.png
# Resized and saved 0105.png
# Resized and saved 0106.png
# Resized and saved 0107.png
# Resized and saved 0108.png
# Resized and saved 0109.png
# Resized and saved 0110.png
# Resized and saved 0111.png
# Resized and saved 0112.png
# Resized and saved 0113.png
# Resized and saved 0114.png
# Resized and saved 0115.png
# Resized and saved 0116.png
# Resized and saved 0117.png
# Resized and saved 0118.png
# Resized and saved 0119.png
# Resized and saved 0120.png
# Resized and saved 0121.png
# Resized and saved 0122.png
# Resized and saved 0123.png
# Resized and saved 0124.png
# Resized and saved 0125.png
# Resized and saved 0126.png
# Resized and saved 0127.png
# Resized and saved 0128.png
# Resized and saved 0129.png
# Resized and saved 0130.png
# Resized and saved 0131.png
# Resized and saved 0132.png
# Resized and saved 0133.png
# Resized and saved 0134.png
# Resized and saved 0135.png
# Resized and saved 0136.png
# Resized and saved 0137.png
# Resized and saved 0138.png
# Resized and saved 0139.png
# Resized and saved 0140.png
# Resized and saved 0141.png
# Resized and saved 0142.png
# Resized and saved 0143.png
# Resized and saved 0144.png
# Resized and saved 0145.png
# Resized and saved 0146.png
# Resized and saved 0147.png
# Resized and saved 0148.png
# Resized and saved 0149.png
# Resized and saved 0150.png
# Resized and saved 0151.png
# Resized and saved 0152.png
# Resized and saved 0153.png
# Resized and saved 0154.png
# Resized and saved 0155.png
# Resized and saved 0156.png
# Resized and saved 0157.png
# Resized and saved 0158.png
# Resized and saved 0159.png
# Resized and saved 0160.png
# Resized and saved 0161.png
# Resized and saved 0162.png
# Resized and saved 0163.png
# Resized and saved 0164.png
# Resized and saved 0165.png
# Resized and saved 0166.png
# Resized and saved 0167.png
# Resized and saved 0168.png
# Resized and saved 0169.png
# Resized and saved 0170.png
# Resized and saved 0171.png
# Resized and saved 0172.png
# Resized and saved 0173.png
# Resized and saved 0174.png
# Resized and saved 0175.png
# Resized and saved 0176.png
# Resized and saved 0177.png
# Resized and saved 0178.png
# Resized and saved 0179.png
# Resized and saved 0180.png
# Resized and saved 0181.png
# Resized and saved 0182.png
# Resized and saved 0183.png
# Resized and saved 0184.png
# Resized and saved 0185.png
# Resized and saved 0186.png
# Resized and saved 0187.png
# Resized and saved 0188.png
# Resized and saved 0189.png
# Resized and saved 0190.png
# Resized and saved 0191.png
# Resized and saved 0192.png
# Resized and saved 0193.png
# Resized and saved 0194.png
# Resized and saved 0195.png
# Resized and saved 0196.png
# Resized and saved 0197.png
# Resized and saved 0198.png
# Resized and saved 0199.png
# Resized and saved 0200.png
# Resized and saved 0201.png
# Resized and saved 0202.png
# Resized and saved 0203.png
# Resized and saved 0204.png
# Resized and saved 0205.png
# Resized and saved 0206.png
# Resized and saved 0207.png
# Resized and saved 0208.png
# Resized and saved 0209.png
# Resized and saved 0210.png
# Resized and saved 0211.png
# Resized and saved 0212.png
# Resized and saved 0213.png
# Resized and saved 0214.png
# Resized and saved 0215.png
# Resized and saved 0216.png
# Resized and saved 0217.png
# Resized and saved 0218.png
# Resized and saved 0219.png
# Resized and saved 0220.png
# Resized and saved 0221.png
# Resized and saved 0222.png
# Resized and saved 0223.png
# Resized and saved 0224.png
# Resized and saved 0225.png
# Resized and saved 0226.png
# Resized and saved 0227.png
# Resized and saved 0228.png
# Resized and saved 0229.png
# Resized and saved 0230.png
# Resized and saved 0231.png
# Resized and saved 0232.png
# Resized and saved 0233.png
# Resized and saved 0234.png
# Resized and saved 0235.png
# Resized and saved 0236.png
# Resized and saved 0237.png
# Resized and saved 0238.png
# Resized and saved 0239.png
# Resized and saved 0240.png
# Resized and saved 0241.png
# Resized and saved 0242.png
# Resized and saved 0243.png
# Resized and saved 0244.png
# Resized and saved 0245.png
# Resized and saved 0246.png
# Resized and saved 0247.png
# Resized and saved 0248.png
# Resized and saved 0249.png
# Resized and saved 0250.png
# Resized and saved 0251.png
# Resized and saved 0252.png
# Resized and saved 0253.png
# Resized and saved 0254.png
# Resized and saved 0255.png
# Resized and saved 0256.png
# Resized and saved 0257.png
# Resized and saved 0258.png
# Resized and saved 0259.png
# Resized and saved 0260.png
# Resized and saved 0261.png
# Resized and saved 0262.png
# Resized and saved 0263.png
# Resized and saved 0264.png
# Resized and saved 0265.png
# Resized and saved 0266.png
# Resized and saved 0267.png
# Resized and saved 0268.png
# Resized and saved 0269.png
# Resized and saved 0270.png
# Resized and saved 0271.png
# Resized and saved 0272.png
# Resized and saved 0273.png
# Resized and saved 0274.png
# Resized and saved 0275.png
# Resized and saved 0276.png
# Resized and saved 0277.png
# Resized and saved 0278.png
# Resized and saved 0279.png
# Resized and saved 0280.png
# Resized and saved 0281.png
# Resized and saved 0282.png
# Resized and saved 0283.png
# Resized and saved 0284.png
# Resized and saved 0285.png
# Resized and saved 0286.png
# Resized and saved 0287.png
# Resized and saved 0288.png
# Resized and saved 0289.png
# Resized and saved 0290.png
# Resized and saved 0291.png
# Resized and saved 0292.png
# Resized and saved 0293.png
# Resized and saved 0294.png
# Resized and saved 0295.png
# Resized and saved 0296.png
# Resized and saved 0297.png
# Resized and saved 0298.png
# Resized and saved 0299.png
# Resized and saved 0300.png
# Resized and saved 0301.png
# Resized and saved 0302.png
# Resized and saved 0303.png
# Resized and saved 0304.png
# Resized and saved 0305.png
# Resized and saved 0306.png
# Resized and saved 0307.png
# Resized and saved 0308.png
# Resized and saved 0309.png
# Resized and saved 0310.png
# Resized and saved 0311.png
# Resized and saved 0312.png
# Resized and saved 0313.png
# Resized and saved 0314.png
# Resized and saved 0315.png
# Resized and saved 0316.png
# Resized and saved 0317.png
# Resized and saved 0318.png
# Resized and saved 0319.png
# Resized and saved 0320.png
# Resized and saved 0321.png
# Resized and saved 0322.png
# Resized and saved 0323.png
# Resized and saved 0324.png
# Resized and saved 0325.png
# Resized and saved 0326.png
# Resized and saved 0327.png
# Resized and saved 0328.png
# Resized and saved 0329.png
# Resized and saved 0330.png
# Resized and saved 0331.png
# Resized and saved 0332.png
# Resized and saved 0333.png
# Resized and saved 0334.png
# Resized and saved 0335.png
# Resized and saved 0336.png
# Resized and saved 0337.png
# Resized and saved 0338.png
# Resized and saved 0339.png
# Resized and saved 0340.png
# Resized and saved 0341.png
# Resized and saved 0342.png
# Resized and saved 0343.png
# Resized and saved 0344.png
# Resized and saved 0345.png
# Resized and saved 0346.png
# Resized and saved 0347.png
# Resized and saved 0348.png
# Resized and saved 0349.png
# Resized and saved 0350.png
# Resized and saved 0351.png
# Resized and saved 0352.png
# Resized and saved 0353.png
# Resized and saved 0354.png
# Resized and saved 0355.png
# Resized and saved 0356.png
# Resized and saved 0357.png
# Resized and saved 0358.png
# Resized and saved 0359.png
# Resized and saved 0360.png
# Resized and saved 0361.png
# Resized and saved 0362.png
# Resized and saved 0363.png
# Resized and saved 0364.png
# Resized and saved 0365.png
# Resized and saved 0366.png
# Resized and saved 0367.png
# Resized and saved 0368.png
# Resized and saved 0369.png
# Resized and saved 0370.png
# Resized and saved 0371.png
# Resized and saved 0372.png
# Resized and saved 0373.png
# Resized and saved 0374.png
# Resized and saved 0375.png
# Resized and saved 0376.png
# Resized and saved 0377.png
# Resized and saved 0378.png
# Resized and saved 0379.png
# Resized and saved 0380.png
# Resized and saved 0381.png
# Resized and saved 0382.png
# Resized and saved 0383.png
# Resized and saved 0384.png
# Resized and saved 0385.png
# Resized and saved 0386.png
# Resized and saved 0387.png
# Resized and saved 0388.png
# Resized and saved 0389.png
# Resized and saved 0390.png
# Resized and saved 0391.png
# Resized and saved 0392.png
# Resized and saved 0393.png
# Resized and saved 0394.png
# Resized and saved 0395.png
# Resized and saved 0396.png
# Resized and saved 0397.png
# Resized and saved 0398.png
# Resized and saved 0399.png
# Resized and saved 0400.png
# Resized and saved 0401.png
# Resized and saved 0402.png
# Resized and saved 0403.png
# Resized and saved 0404.png
# Resized and saved 0405.png
# Resized and saved 0406.png
# Resized and saved 0407.png
# Resized and saved 0408.png
# Resized and saved 0409.png
# Resized and saved 0410.png
# Resized and saved 0411.png
# Resized and saved 0412.png
# Resized and saved 0413.png
# Resized and saved 0414.png
# Resized and saved 0415.png
# Resized and saved 0416.png
# Resized and saved 0417.png
# Resized and saved 0418.png
# Resized and saved 0419.png
# Resized and saved 0420.png
# Resized and saved 0421.png
# Resized and saved 0422.png
# Resized and saved 0423.png
# Resized and saved 0424.png
# Resized and saved 0425.png
# Resized and saved 0426.png
# Resized and saved 0427.png
# Resized and saved 0428.png
# Resized and saved 0429.png
# Resized and saved 0430.png
# Resized and saved 0431.png
# Resized and saved 0432.png
# Resized and saved 0433.png
# Resized and saved 0434.png
# Resized and saved 0435.png
# Resized and saved 0436.png
# Resized and saved 0437.png
# Resized and saved 0438.png
# Resized and saved 0439.png
# Resized and saved 0440.png
# Resized and saved 0441.png
# Resized and saved 0442.png
# Resized and saved 0443.png
# Resized and saved 0444.png
# Resized and saved 0445.png
# Resized and saved 0446.png
# Resized and saved 0447.png
# Resized and saved 0448.png
# Resized and saved 0449.png
# Resized and saved 0450.png
# Resized and saved 0451.png
# Resized and saved 0452.png
# Resized and saved 0453.png
# Resized and saved 0454.png
# Resized and saved 0455.png
# Resized and saved 0456.png
# Resized and saved 0457.png
# Resized and saved 0458.png
# Resized and saved 0459.png
# Resized and saved 0460.png
# Resized and saved 0461.png
# Resized and saved 0462.png
# Resized and saved 0463.png
# Resized and saved 0464.png
# Resized and saved 0465.png
# Resized and saved 0466.png
# Resized and saved 0467.png
# Resized and saved 0468.png
# Resized and saved 0469.png
# Resized and saved 0470.png
# Resized and saved 0471.png
# Resized and saved 0472.png
# Resized and saved 0473.png
# Resized and saved 0474.png
# Resized and saved 0475.png
# Resized and saved 0476.png
# Resized and saved 0477.png
# Resized and saved 0478.png
# Resized and saved 0479.png
# Resized and saved 0480.png
# Resized and saved 0481.png
# Resized and saved 0482.png
# Resized and saved 0483.png
# Resized and saved 0484.png
# Resized and saved 0485.png
# Resized and saved 0486.png
# Resized and saved 0487.png
# Resized and saved 0488.png
# Resized and saved 0489.png
# Resized and saved 0490.png
# Resized and saved 0491.png
# Resized and saved 0492.png
# Resized and saved 0493.png
# Resized and saved 0494.png
# Resized and saved 0495.png
# Resized and saved 0496.png
# Resized and saved 0497.png
# Resized and saved 0498.png
# Resized and saved 0499.png
# Resized and saved 0500.png
# Resized and saved 0501.png
# Resized and saved 0502.png
# Resized and saved 0503.png
# Resized and saved 0504.png
# Resized and saved 0505.png
# Resized and saved 0506.png
# Resized and saved 0507.png
# Resized and saved 0508.png
# Resized and saved 0509.png
# Resized and saved 0510.png
# Resized and saved 0511.png
# Resized and saved 0512.png
# Resized and saved 0513.png
# Resized and saved 0514.png
# Resized and saved 0515.png
# Resized and saved 0516.png
# Resized and saved 0517.png
# Resized and saved 0518.png
# Resized and saved 0519.png
# Resized and saved 0520.png
# Resized and saved 0521.png
# Resized and saved 0522.png
# Resized and saved 0523.png
# Resized and saved 0524.png
# Resized and saved 0525.png
# Resized and saved 0526.png
# Resized and saved 0527.png
# Resized and saved 0528.png
# Resized and saved 0529.png
# Resized and saved 0530.png
# Resized and saved 0531.png
# Resized and saved 0532.png
# Resized and saved 0533.png
# Resized and saved 0534.png
# Resized and saved 0535.png
# Resized and saved 0536.png
# Resized and saved 0537.png
# Resized and saved 0538.png
# Resized and saved 0539.png
# Resized and saved 0540.png
# Resized and saved 0541.png
# Resized and saved 0542.png
# Resized and saved 0543.png
# Resized and saved 0544.png
# Resized and saved 0545.png
# Resized and saved 0546.png
# Resized and saved 0547.png
# Resized and saved 0548.png
# Resized and saved 0549.png
# Resized and saved 0550.png
# Resized and saved 0551.png
# Resized and saved 0552.png
# Resized and saved 0553.png
# Resized and saved 0554.png
# Resized and saved 0555.png
# Resized and saved 0556.png
# Resized and saved 0557.png
# Resized and saved 0558.png
# Resized and saved 0559.png
# Resized and saved 0560.png
# Resized and saved 0561.png
# Resized and saved 0562.png
# Resized and saved 0563.png
# Resized and saved 0564.png
# Resized and saved 0565.png
# Resized and saved 0566.png
# Resized and saved 0567.png
# Resized and saved 0568.png
# Resized and saved 0569.png
# Resized and saved 0570.png
# Resized and saved 0571.png
# Resized and saved 0572.png
# Resized and saved 0573.png
# Resized and saved 0574.png
# Resized and saved 0575.png
# Resized and saved 0576.png
# Resized and saved 0577.png
# Resized and saved 0578.png
# Resized and saved 0579.png
# Resized and saved 0580.png
# Resized and saved 0581.png
# Resized and saved 0582.png
# Resized and saved 0583.png
# Resized and saved 0584.png
# Resized and saved 0585.png
# Resized and saved 0586.png
# Resized and saved 0587.png
# Resized and saved 0588.png
# Resized and saved 0589.png
# Resized and saved 0590.png
# Resized and saved 0591.png
# Resized and saved 0592.png
# Resized and saved 0593.png
# Resized and saved 0594.png
# Resized and saved 0595.png
# Resized and saved 0596.png
# Resized and saved 0597.png
# Resized and saved 0598.png
# Resized and saved 0599.png
# Resized and saved 0600.png
# Resized and saved 0601.png
# Resized and saved 0602.png
# Resized and saved 0603.png
# Resized and saved 0604.png
# Resized and saved 0605.png
# Resized and saved 0606.png
# Resized and saved 0607.png
# Resized and saved 0608.png
# Resized and saved 0609.png
# Resized and saved 0610.png
# Resized and saved 0611.png
# Resized and saved 0612.png
# Resized and saved 0613.png
# Resized and saved 0614.png
# Resized and saved 0615.png
# Resized and saved 0616.png
# Resized and saved 0617.png
# Resized and saved 0618.png
# Resized and saved 0619.png
# Resized and saved 0620.png
# Resized and saved 0621.png
# Resized and saved 0622.png
# Resized and saved 0623.png
# Resized and saved 0624.png
# Resized and saved 0625.png
# Resized and saved 0626.png
# Resized and saved 0627.png
# Resized and saved 0628.png
# Resized and saved 0629.png
# Resized and saved 0630.png
# Resized and saved 0631.png
# Resized and saved 0632.png
# Resized and saved 0633.png
# Resized and saved 0634.png
# Resized and saved 0635.png
# Resized and saved 0636.png
# Resized and saved 0637.png
# Resized and saved 0638.png
# Resized and saved 0639.png
# Resized and saved 0640.png
# Resized and saved 0641.png
# Resized and saved 0642.png
# Resized and saved 0643.png
# Resized and saved 0644.png
# Resized and saved 0645.png
# Resized and saved 0646.png
# Resized and saved 0647.png
# Resized and saved 0648.png
# Resized and saved 0649.png
# Resized and saved 0650.png
# Resized and saved 0651.png
# Resized and saved 0652.png
# Resized and saved 0653.png
# Resized and saved 0654.png
# Resized and saved 0655.png
# Resized and saved 0656.png
# Resized and saved 0657.png
# Resized and saved 0658.png
# Resized and saved 0659.png
# Resized and saved 0660.png
# Resized and saved 0661.png
# Resized and saved 0662.png
# Resized and saved 0663.png
# Resized and saved 0664.png
# Resized and saved 0665.png
# Resized and saved 0666.png
# Resized and saved 0667.png
# Resized and saved 0668.png
# Resized and saved 0669.png
# Resized and saved 0670.png
# Resized and saved 0671.png
# Resized and saved 0672.png
# Resized and saved 0673.png
# Resized and saved 0674.png
# Resized and saved 0675.png
# Resized and saved 0676.png
# Resized and saved 0677.png
# Resized and saved 0678.png
# Resized and saved 0679.png
# Resized and saved 0680.png
# Resized and saved 0681.png
# Resized and saved 0682.png
# Resized and saved 0683.png
# Resized and saved 0684.png
# Resized and saved 0685.png
# Resized and saved 0686.png
# Resized and saved 0687.png
# Resized and saved 0688.png
# Resized and saved 0689.png
# Resized and saved 0690.png
# Resized and saved 0691.png
# Resized and saved 0692.png
# Resized and saved 0693.png
# Resized and saved 0694.png
# Resized and saved 0695.png
# Resized and saved 0696.png
# Resized and saved 0697.png
# Resized and saved 0698.png
# Resized and saved 0699.png
# Resized and saved 0700.png
# Resized and saved 0701.png
# Resized and saved 0702.png
# Resized and saved 0703.png
# Resized and saved 0704.png
# Resized and saved 0705.png
# Resized and saved 0706.png
# Resized and saved 0707.png
# Resized and saved 0708.png
# Resized and saved 0709.png
# Resized and saved 0710.png
# Resized and saved 0711.png
# Resized and saved 0712.png
# Resized and saved 0713.png
# Resized and saved 0714.png
# Resized and saved 0715.png
# Resized and saved 0716.png
# Resized and saved 0717.png
# Resized and saved 0718.png
# Resized and saved 0719.png
# Resized and saved 0720.png
# Resized and saved 0721.png
# Resized and saved 0722.png
# Resized and saved 0723.png
# Resized and saved 0724.png
# Resized and saved 0725.png
# Resized and saved 0726.png
# Resized and saved 0727.png
# Resized and saved 0728.png
# Resized and saved 0729.png
# Resized and saved 0730.png
# Resized and saved 0731.png
# Resized and saved 0732.png
# Resized and saved 0733.png
# Resized and saved 0734.png
# Resized and saved 0735.png
# Resized and saved 0736.png
# Resized and saved 0737.png
# Resized and saved 0738.png
# Resized and saved 0739.png
# Resized and saved 0740.png
# Resized and saved 0741.png
# Resized and saved 0742.png
# Resized and saved 0743.png
# Resized and saved 0744.png
# Resized and saved 0745.png
# Resized and saved 0746.png
# Resized and saved 0747.png
# Resized and saved 0748.png
# Resized and saved 0749.png
# Resized and saved 0750.png
# Resized and saved 0751.png
# Resized and saved 0752.png
# Resized and saved 0753.png
# Resized and saved 0754.png
# Resized and saved 0755.png
# Resized and saved 0756.png
# Resized and saved 0757.png
# Resized and saved 0758.png
# Resized and saved 0759.png
# Resized and saved 0760.png
# Resized and saved 0761.png
# Resized and saved 0762.png
# Resized and saved 0763.png
# Resized and saved 0764.png
# Resized and saved 0765.png
# Resized and saved 0766.png
# Resized and saved 0767.png
# Resized and saved 0768.png
# Resized and saved 0769.png
# Resized and saved 0770.png
# Resized and saved 0771.png
# Resized and saved 0772.png
# Resized and saved 0773.png
# Resized and saved 0774.png
# Resized and saved 0775.png
# Resized and saved 0776.png
# Resized and saved 0777.png
# Resized and saved 0778.png
# Resized and saved 0779.png
# Resized and saved 0780.png
# Resized and saved 0781.png
# Resized and saved 0782.png
# Resized and saved 0783.png
# Resized and saved 0784.png
# Resized and saved 0785.png
# Resized and saved 0786.png
# Resized and saved 0787.png
# Resized and saved 0788.png
# Resized and saved 0789.png
# Resized and saved 0790.png
# Resized and saved 0791.png
# Resized and saved 0792.png
# Resized and saved 0793.png
# Resized and saved 0794.png
# Resized and saved 0795.png
# Resized and saved 0796.png
# Resized and saved 0797.png
# Resized and saved 0798.png
# Resized and saved 0799.png
# Resized and saved 0800.png
# Resized and saved 0801.png
# Resized and saved 0802.png
# Resized and saved 0803.png
# Resized and saved 0804.png
# Resized and saved 0805.png
# Resized and saved 0806.png
# Resized and saved 0807.png
# Resized and saved 0808.png
# Resized and saved 0809.png
# Resized and saved 0810.png
# Resized and saved 0811.png
# Resized and saved 0812.png
# Resized and saved 0813.png
# Resized and saved 0814.png
# Resized and saved 0815.png
# Resized and saved 0816.png
# Resized and saved 0817.png
# Resized and saved 0818.png
# Resized and saved 0819.png
# Resized and saved 0820.png
# Resized and saved 0821.png
# Resized and saved 0822.png
# Resized and saved 0823.png
# Resized and saved 0824.png
# Resized and saved 0825.png
# Resized and saved 0826.png
# Resized and saved 0827.png
# Resized and saved 0828.png
# Resized and saved 0829.png
# Resized and saved 0830.png
# Resized and saved 0831.png
# Resized and saved 0832.png
# Resized and saved 0833.png
# Resized and saved 0834.png
# Resized and saved 0835.png
# Resized and saved 0836.png
# Resized and saved 0837.png
# Resized and saved 0838.png
# Resized and saved 0839.png
# Resized and saved 0840.png
# Resized and saved 0841.png
# Resized and saved 0842.png
# Resized and saved 0843.png
# Resized and saved 0844.png
# Resized and saved 0845.png
# Resized and saved 0846.png
# Resized and saved 0847.png
# Resized and saved 0848.png
# Resized and saved 0849.png
# Resized and saved 0850.png
# Resized and saved 0851.png
# Resized and saved 0852.png
# Resized and saved 0853.png
# Resized and saved 0854.png
# Resized and saved 0855.png
# Resized and saved 0856.png
# Resized and saved 0857.png
# Resized and saved 0858.png
# Resized and saved 0859.png
# Resized and saved 0860.png
# Resized and saved 0861.png
# Resized and saved 0862.png
# Resized and saved 0863.png
# Resized and saved 0864.png
# Resized and saved 0865.png
# Resized and saved 0866.png
# Resized and saved 0867.png
# Resized and saved 0868.png
# Resized and saved 0869.png
# Resized and saved 0870.png
# Resized and saved 0871.png
# Resized and saved 0872.png
# Resized and saved 0873.png
# Resized and saved 0874.png
# Resized and saved 0875.png
# Resized and saved 0876.png
# Resized and saved 0877.png
# Resized and saved 0878.png
# Resized and saved 0879.png
# Resized and saved 0880.png
# Resized and saved 0881.png
# Resized and saved 0882.png
# Resized and saved 0883.png
# Resized and saved 0884.png
# Resized and saved 0885.png
# Resized and saved 0886.png
# Resized and saved 0887.png
# Resized and saved 0888.png
# Resized and saved 0889.png
# Resized and saved 0890.png
# Resized and saved 0891.png
# Resized and saved 0892.png
# Resized and saved 0893.png
# Resized and saved 0894.png
# Resized and saved 0895.png
# Resized and saved 0896.png
# Resized and saved 0897.png
# Resized and saved 0898.png
# Resized and saved 0899.png
# Resized and saved 0900.png
# Resized and saved 0901.png
# Resized and saved 0902.png
# Resized and saved 0903.png
# Resized and saved 0904.png
# Resized and saved 0905.png
# Resized and saved 0906.png
# Resized and saved 0907.png
# Resized and saved 0908.png
# Resized and saved 0909.png
# Resized and saved 0910.png
# Resized and saved 0911.png
# Resized and saved 0912.png
# Resized and saved 0913.png
# Resized and saved 0914.png
# Resized and saved 0915.png
# Resized and saved 0916.png
# Resized and saved 0917.png
# Resized and saved 0918.png
# Resized and saved 0919.png
# Resized and saved 0920.png
# Resized and saved 0921.png
# Resized and saved 0922.png
# Resized and saved 0923.png
# Resized and saved 0924.png
# Resized and saved 0925.png
# Resized and saved 0926.png
# Resized and saved 0927.png
# Resized and saved 0928.png
# Resized and saved 0929.png
# Resized and saved 0930.png
# Resized and saved 0931.png
# Resized and saved 0932.png
# Resized and saved 0933.png
# Resized and saved 0934.png
# Resized and saved 0935.png
# Resized and saved 0936.png
# Resized and saved 0937.png
# Resized and saved 0938.png
# Resized and saved 0939.png
# Resized and saved 0940.png
# Resized and saved 0941.png
# Resized and saved 0942.png
# Resized and saved 0943.png
# Resized and saved 0944.png
# Resized and saved 0945.png
# Resized and saved 0946.png
# Resized and saved 0947.png
# Resized and saved 0948.png
# Resized and saved 0949.png
# Resized and saved 0950.png
# Resized and saved 0951.png
# Resized and saved 0952.png
# Resized and saved 0953.png
# Resized and saved 0954.png
# Resized and saved 0955.png
# Resized and saved 0956.png
# Resized and saved 0957.png
# Resized and saved 0958.png
# Resized and saved 0959.png
# Resized and saved 0960.png
# Resized and saved 0961.png
# Resized and saved 0962.png
# Resized and saved 0963.png
# Resized and saved 0964.png
# Resized and saved 0965.png
# Resized and saved 0966.png
# Resized and saved 0967.png
# Resized and saved 0968.png
# Resized and saved 0969.png
# Resized and saved 0970.png
# Resized and saved 0971.png
# Resized and saved 0972.png
# Resized and saved 0973.png
# Resized and saved 0974.png
# Resized and saved 0975.png
# Resized and saved 0976.png
# Resized and saved 0977.png
# Resized and saved 0978.png
# Resized and saved 0979.png
# Resized and saved 0980.png
# Resized and saved 0981.png
# Resized and saved 0982.png
# Resized and saved 0983.png
# Resized and saved 0984.png
# Resized and saved 0985.png
# Resized and saved 0986.png
# Resized and saved 0987.png
# Resized and saved 0988.png
# Resized and saved 0989.png
# Resized and saved 0990.png
# Resized and saved 0991.png
# Resized and saved 0992.png
# Resized and saved 0993.png
# Resized and saved 0994.png
# Resized and saved 0995.png
# Resized and saved 0996.png
# Resized and saved 0997.png
# Resized and saved 0998.png
# Resized and saved 0999.png
# Resized and saved 1000.png
# Images and masks have been resized and saved.
# Dataset has been split into training, validation, and test sets.
# Number of training images: 700
# Number of validation images: 100
# Number of test images: 200

# %%
class ECSSDDataset(Dataset):
    def __init__(self, image_list, image_dir, mask_dir, image_transform=None, mask_transform=None):
        self.image_list = image_list
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_transform = image_transform
        self.mask_transform = mask_transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        img_name = self.image_list[idx]
        img_path = os.path.join(self.image_dir, img_name)
        
        # Handle both .jpg and .png extensions for masks
        mask_name = img_name.replace('.jpg', '.png') if img_name.endswith('.jpg') else img_name
        mask_path = os.path.join(self.mask_dir, mask_name)

        image = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")

        if self.image_transform:
            image = self.image_transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)

        return image, mask

image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

mask_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Datasets and DataLoaders
train_dataset = ECSSDDataset(train_images, resized_image_path, resized_mask_path, image_transform, mask_transform)
val_dataset = ECSSDDataset(val_images, resized_image_path, resized_mask_path, image_transform, mask_transform)
test_dataset = ECSSDDataset(test_images, resized_image_path, resized_mask_path, image_transform, mask_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Dice Coefficient Loss
class DiceLoss(nn.Module):
    def __init__(self):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        intersection = (inputs * targets).sum()
        dice = (2. * intersection + smooth) / (inputs.sum() + targets.sum() + smooth)
        return 1 - dice

# %% [markdown]
# ## #1

# %%
class GoogLeNetSegmentation(nn.Module):
    def __init__(self, num_classes=1):
        super(GoogLeNetSegmentation, self).__init__()
        googlenet = models.googlenet(pretrained=True)
        # Remove the final layers
        self.features = nn.Sequential(*list(googlenet.children())[:-2])
        self.conv1x1 = nn.Conv2d(1024, num_classes, kernel_size=1)

    def forward(self, x):
        # Get features from GoogLeNet
        x = self.features(x)
        # Apply 1x1 convolution
        x = self.conv1x1(x)
        # Upsample to original size
        x = nn.functional.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)
        return torch.sigmoid(x)

# %% [markdown]
# ## #2

# %%
class ResNetSegmentation(nn.Module):
    def __init__(self, num_classes=1):
        super(ResNetSegmentation, self).__init__()
        resnet = models.resnet50(pretrained=True)
        # Remove the final layers
        self.features = nn.Sequential(*list(resnet.children())[:-2])
        self.conv1x1 = nn.Conv2d(2048, num_classes, kernel_size=1)

    def forward(self, x):
        # Get features from ResNet
        x = self.features(x)
        # Apply 1x1 convolution
        x = self.conv1x1(x)
        # Upsample to original size
        x = nn.functional.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)
        return torch.sigmoid(x)

# %% [markdown]
# ## Training

# %%
# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    best_model_wts = model.state_dict()
    best_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
                dataloader = train_loader
            else:
                model.eval()  # Set model to evaluate mode
                dataloader = val_loader

            running_loss = 0.0

            # Iterate over data.
            for inputs, masks in dataloader:
                inputs = inputs.to(device)
                masks = masks.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, masks)

                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloader.dataset)

            print(f'{phase} Loss: {epoch_loss:.4f}')

            # Deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = model.state_dict()

    print('Best val loss: {:4f}'.format(best_loss))

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model

# Initialize models, loss, and optimizer
googlenet_model = GoogLeNetSegmentation()
resnet_model = ResNetSegmentation()
criterion = DiceLoss()
googlenet_optimizer = optim.Adam(googlenet_model.parameters(), lr=1e-4)
resnet_optimizer = optim.Adam(resnet_model.parameters(), lr=1e-4)

# Move models to device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
googlenet_model = googlenet_model.to(device)
resnet_model = resnet_model.to(device)

# Train GoogLeNet model
print("Training GoogLeNet model...")
googlenet_model = train_model(googlenet_model, train_loader, val_loader, criterion, googlenet_optimizer, num_epochs=25)

# Train ResNet model
print("Training ResNet model...")
resnet_model = train_model(resnet_model, train_loader, val_loader, criterion, resnet_optimizer, num_epochs=25)

# Testing function
def test_model(model, test_loader):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()
    dice_scores = []

    with torch.no_grad():
        for inputs, masks in test_loader:
            inputs = inputs.to(device)
            masks = masks.to(device)
            outputs = model(inputs)
            dice_loss = DiceLoss()
            dice_score = 1 - dice_loss(outputs, masks).item()
            dice_scores.append(dice_score)

    mean_dice_score = np.mean(dice_scores)
    print(f'Mean Dice Score: {mean_dice_score:.4f}')

# Test GoogLeNet model
print("Testing GoogLeNet model...")
test_model(googlenet_model, test_loader)

# Test ResNet model
print("Testing ResNet model...")
test_model(resnet_model, test_loader)
# Out:
# c:\Users\Vaishnav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Vaishnav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\Vaishnav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Training GoogLeNet model...
# Epoch 0/24
# ----------
# train Loss: 0.6423
# val Loss: 0.6077
# Epoch 1/24
# ----------
# train Loss: 0.5890
# val Loss: 0.5806
# Epoch 2/24
# ----------
# train Loss: 0.5680
# val Loss: 0.5733
# Epoch 3/24
# ----------
# train Loss: 0.5578
# val Loss: 0.5695
# Epoch 4/24
# ----------
# train Loss: 0.5519
# val Loss: 0.5674
# Epoch 5/24
# ----------
# train Loss: 0.5469
# val Loss: 0.5623
# Epoch 6/24
# ----------
# train Loss: 0.5415
# val Loss: 0.5595
# Epoch 7/24
# ----------
# train Loss: 0.5395
# val Loss: 0.5575
# Epoch 8/24
# ----------
# train Loss: 0.5384
# val Loss: 0.5575
# Epoch 9/24
# ----------
# train Loss: 0.5378
# val Loss: 0.5580
# Epoch 10/24
# ----------
# train Loss: 0.5419
# val Loss: 0.5581
# Epoch 11/24
# ----------
# train Loss: 0.5377
# val Loss: 0.5588
# Epoch 12/24
# ----------
# train Loss: 0.5366
# val Loss: 0.5606
# Epoch 13/24
# ----------
# train Loss: 0.5373
# val Loss: 0.5595
# Epoch 14/24
# ----------
# train Loss: 0.5373
# val Loss: 0.5564
# Epoch 15/24
# ----------
# train Loss: 0.5378
# val Loss: 0.5561
# Epoch 16/24
# ----------
# train Loss: 0.5372
# val Loss: 0.5558
# Epoch 17/24
# ----------
# train Loss: 0.5349
# val Loss: 0.5561
# Epoch 18/24
# ----------
# train Loss: 0.5366
# val Loss: 0.5539
# Epoch 19/24
# ----------
# train Loss: 0.5366
# val Loss: 0.5573
# Epoch 20/24
# ----------
# train Loss: 0.5368
# val Loss: 0.5599
# Epoch 21/24
# ----------
# train Loss: 0.5376
# val Loss: 0.5532
# Epoch 22/24
# ----------
# train Loss: 0.5371
# val Loss: 0.5612
# Epoch 23/24
# ----------
# train Loss: 0.5384
# val Loss: 0.5611
# Epoch 24/24
# ----------
# train Loss: 0.5378
# val Loss: 0.5671
# Best val loss: 0.553162
# Training ResNet model...
# Epoch 0/24
# ----------
# train Loss: 0.4029
# val Loss: 0.3336
# Epoch 1/24
# ----------
# train Loss: 0.1985
# val Loss: 0.1830
# Epoch 2/24
# ----------
# train Loss: 0.1536
# val Loss: 0.1674
# Epoch 3/24
# ----------
# train Loss: 0.1305
# val Loss: 0.1647
# Epoch 4/24
# ----------
# train Loss: 0.1175
# val Loss: 0.1532
# Epoch 5/24
# ----------
# train Loss: 0.1121
# val Loss: 0.1471
# Epoch 6/24
# ----------
# train Loss: 0.1040
# val Loss: 0.1421
# Epoch 7/24
# ----------
# train Loss: 0.0977
# val Loss: 0.1457
# Epoch 8/24
# ----------
# train Loss: 0.0936
# val Loss: 0.1381
# Epoch 9/24
# ----------
# train Loss: 0.0903
# val Loss: 0.1370
# Epoch 10/24
# ----------
# train Loss: 0.0879
# val Loss: 0.1368
# Epoch 11/24
# ----------
# train Loss: 0.0849
# val Loss: 0.1317
# Epoch 12/24
# ----------
# train Loss: 0.0840
# val Loss: 0.1347
# Epoch 13/24
# ----------
# train Loss: 0.0816
# val Loss: 0.1327
# Epoch 14/24
# ----------
# train Loss: 0.0807
# val Loss: 0.1298
# Epoch 15/24
# ----------
# train Loss: 0.0794
# val Loss: 0.1314
# Epoch 16/24
# ----------
# train Loss: 0.0774
# val Loss: 0.1287
# Epoch 17/24
# ----------
# train Loss: 0.0757
# val Loss: 0.1301
# Epoch 18/24
# ----------
# train Loss: 0.0748
# val Loss: 0.1274
# Epoch 19/24
# ----------
# train Loss: 0.0747
# val Loss: 0.1289
# Epoch 20/24
# ----------
# train Loss: 0.0738
# val Loss: 0.1300
# Epoch 21/24
# ----------
# train Loss: 0.0743
# val Loss: 0.1294
# Epoch 22/24
# ----------
# train Loss: 0.0740
# val Loss: 0.1288
# Epoch 23/24
# ----------
# train Loss: 0.0728
# val Loss: 0.1304
# Epoch 24/24
# ----------
# train Loss: 0.0712
# val Loss: 0.1286
# Best val loss: 0.127433
# Testing GoogLeNet model...
# Mean Dice Score: 0.3912
# Testing ResNet model...
# Mean Dice Score: 0.8472

# %% [markdown]
# ResNet score is significantly higher than the GoogLeNet score (0.8472 > 0.3912). Hence, ResNet is obviously the better model for this segmentation task.
